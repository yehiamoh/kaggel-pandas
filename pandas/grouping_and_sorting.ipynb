# %%
import pandas as pd
reviews=pd.read_csv("./data/ramen-ratings.csv")


reviews['Stars'] = pd.to_numeric(reviews['Stars'], errors='coerce') #convert the Stars column into number variable

reviews.groupby('Country').Stars.min() # Group the data by the Country and did and operation to the data related to each country by getting the minimun star each country got
reviews.groupby(['Country','Brand'])["Stars"].agg([min,max,len])

reviews.sort_values(by='Stars',ascending=False)
# Out:
# C:\Users\yehia\AppData\Local\Temp\ipykernel_24948\3012363495.py:8: FutureWarning: The provided callable <built-in function min> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   reviews.groupby(['Country','Brand'])["Stars"].agg([min,max,len])
# C:\Users\yehia\AppData\Local\Temp\ipykernel_24948\3012363495.py:8: FutureWarning: The provided callable <built-in function max> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   reviews.groupby(['Country','Brand'])["Stars"].agg([min,max,len])
#       Review #          Brand  \
# 2552        28         Nissin
# 30        2550  Samyang Foods
# 10        2570    Tao Kae Noi
# 11        2569       Yamachan
# 28        2552        MyKuali
# ...        ...            ...
# 53        2527  Uni-President
# ...
