# %%
import pandas as pd

reviews=pd.read_csv('./data/ramen-ratings.csv')

reviews.rename(columns={'Top Ten':'Top Nine'}) # Change column name from Top Ten into Top Nine
reviews.rename(index={0:'firstIndex',1:'secondIndex'}) # Chamge indexes name 


reviews=reviews.rename_axis("reviews", axis='rows').rename_axis("fields", axis='columns') # change the most top left cell (axis) and label


cows_and_goats=pd.read_csv('./data/cows_goats.csv')

pd.concat([reviews,cows_and_goats]) # get a dataframe with combination of two frames

reviews

# powerlifting_combined = powerlifting_meets.set_index("MeetID").join(powerlifting_competitors.set_index("MeetID"))
#Both tables include references to a `MeetID`, a unique key for each meet (competition) included in the database. Using this, generate a dataset combining the two tables into one.
# Out:
# fields   Review #           Brand  \
# reviews
# 0            2580       New Touch
# 1            2579        Just Way
# 2            2578          Nissin
# 3            2577         Wei Lih
# 4            2576  Ching's Secret
# ...           ...             ...
# 2575            5           Vifon
# 2576            4         Wai Wai
# 2577            3         Wai Wai
# 2578            2         Wai Wai
# 2579            1        Westbrae
#
# fields                                             Variety Style   Country  \
# reviews
# 0                                T's Restaurant Tantanmen    Cup     Japan
# 1        Noodles Spicy Hot Sesame Spicy Hot Sesame Guan...  Pack    Taiwan
# 2                            Cup Noodles Chicken Vegetable   Cup       USA
# 3                            GGE Ramen Snack Tomato Flavor  Pack    Taiwan
# 4                                          Singapore Curry  Pack     India
# ...                                                    ...   ...       ...
# ...
